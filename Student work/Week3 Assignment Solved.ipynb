# %% [markdown]
# # Week 3 Assignment

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
tips = sns.load_dataset("tips")
plt.figure(figsize=(8, 6))
tips_avg = tips.groupby("day")["tip"].mean()
plt.bar(tips_avg.index, tips_avg.values)
plt.title("Average Tip by Day")
plt.xlabel("Day")
plt.ylabel("Average Tip")
plt.show()
# Out:
# <ipython-input-8-70098cfa6dda>:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_avg = tips.groupby("day")["tip"].mean()

# %%
import seaborn as sns
import pandas as pd

# Load the tips dataset
tips = sns.load_dataset("tips")
sns.lineplot(x="total_bill", y="tip", data=tips)
plt.title("Tip Amount vs. Total Bill")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()

# %%
import seaborn as sns
import pandas as pd

# Load the tips dataset
tips = sns.load_dataset("tips")
sns.scatterplot(x="total_bill", y="tip", hue="smoker", data=tips)
plt.title("Total Bill vs. Tip by Smoker")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the tips dataset
tips = sns.load_dataset("tips")
plt.figure(figsize=(8, 6))
sex_counts = tips["sex"].value_counts()
plt.pie(sex_counts, labels=sex_counts.index, autopct="%1.1f%%")
plt.title("Distribution of Sex")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the tips dataset
tips = sns.load_dataset("tips")
plt.figure(figsize=(8, 6))
plt.hist(tips["total_bill"], bins=20, density=True, alpha=0.6)
plt.title("Distribution of Total Bill")
plt.xlabel("Total Bill")
plt.ylabel("Density")
plt.show()
